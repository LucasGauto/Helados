# %%
from dotenv import load_dotenv
import os

# Cargar automáticamente las variables del archivo .env
load_dotenv()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

DATA_RAW = os.getenv('DATA_RAW')
DATA_PREPROCESSED = os.getenv('DATA_PROCESSED')
MODELS = os.getenv('MODELS')
df = pd.read_csv(os.path.join('..',DATA_RAW, "dataframe_merged.csv"), sep=";")

df.head(5)

df_features = df.copy()
df_features.drop([f'Sabor {i}' for i in range(1,80)], axis = 1, inplace = True)
df_target = df.loc[:, df.columns.str.startswith("Sabor")].copy()
df_target.head()
# Out:
#    Sabor 1  Sabor 2  Sabor 3  Sabor 4  Sabor 5  Sabor 6  Sabor 7  Sabor 8  \
# 0     5.36    12.45     5.47     5.03      NaN    12.41    11.60     5.60
# 1    22.92      NaN    26.50      NaN      NaN    32.50     5.08     5.12
# 2    34.39      NaN    35.99      NaN      NaN    32.64    20.10    20.37
# 3    10.66      NaN    12.38      NaN      NaN    21.97      NaN    10.21
# 4    11.42      NaN    23.53      NaN      NaN    18.89     5.05     5.07
#
#    Sabor 9  Sabor 10  ...  Sabor 70  Sabor 71  Sabor 72  Sabor 73  Sabor 74  \
# 0     6.22     11.21  ...       NaN       NaN       NaN       NaN       NaN
# 1      NaN     25.26  ...       NaN      1.07       NaN     37.09     43.60
# 2      NaN     49.79  ...       NaN      3.17      3.29     30.47     37.01
# 3      NaN     22.96  ...       NaN       NaN      1.02     11.89     11.54
# 4      NaN     26.02  ...       NaN      1.04      3.06     18.13     25.47
#
#    Sabor 75  Sabor 76  Sabor 77  Sabor 78  Sabor 79
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN      20.0      50.0     28.03     11.63
# 2       NaN      20.0      50.0     25.95     10.61
# 3       NaN      10.0      10.0     11.30      5.59
# 4       NaN      60.0      70.0     12.66     11.94
#
# [5 rows x 79 columns]

# %%
df_features = df_features.rename(
        columns={
            'Ajuste Fecha': 'date',
            'EsFeriado':'holiday',
            'Estacion':'season'
            }
    )
df_features = df_features[['date', 'temp', 'humidity','wind_speed','clouds_all','holiday','season']]
df_features['date'] = pd.to_datetime(df_features['date'])
df_features.drop('season', axis = 1, inplace = True)

# %%
df_features
# Out:
#            date       temp  humidity  wind_speed  clouds_all  holiday
# 0    2022-01-01  25.950400      64.0       3.270        40.0     True
# 1    2022-01-02  25.956667      80.0       2.570         0.5    False
# 2    2022-01-03  28.290400      67.0       2.060         0.0    False
# 3    2022-01-04  26.944615      69.0       4.955         0.0    False
# 4    2022-01-05  24.381250      53.5       4.885         0.0    False
# ...         ...        ...       ...         ...         ...      ...
# 1091 2024-12-27  22.339167      58.5       2.150         0.0    False
# 1092 2024-12-28  24.437500      49.0       2.240         0.0    False
# 1093 2024-12-29  24.166250      52.5       4.470         0.0    False
# 1094 2024-12-30  25.622917      59.5       4.920         0.0    False
# 1095 2024-12-31  27.576667      53.5       4.035         0.0    False
#
# [1096 rows x 6 columns]

# %%
import sys
from pathlib import Path

#Añadír la carpeta src al PYTHONPATH de la sesión 
ROOT = Path.cwd().parent        # .. = carpeta raíz del proyecto
sys.path.append(str(ROOT / "src"))

# Importar mis clases
from features.my_transformers import LagRoller
from features.my_transformers import CyclicalEncoder, InformationOfDateExtractor, SeasonGetter, SeasonOrdinalizer
import joblib
pipeline = joblib.load("../src/features/features_pipeline.joblib")

# %%
X = pipeline.fit_transform(df_features)

# %%
# Funcion para combinar features y target
def concatFeaturesTarget(X:np.array, y:pd.Series, features_columns = list):
    columns = features_columns
    df_full = pd.DataFrame(X, columns = columns)
    df_full['kg'] = y.fillna(0)
    return df_full

# %%
columns = list(pipeline.get_feature_names_out())
target = 'Sabor 1'
concatFeaturesTarget(X, df_target[target], columns)
# Out:
#           temp  humidity wind_speed clouds_all holiday month_sin month_cos  \
# 0     0.744146  0.485714    0.21288        0.4    True       0.5  0.866025
# 1     0.744365  0.714286   0.150268      0.005   False       0.5  0.866025
# 2     0.826019  0.528571   0.104651        0.0   False       0.5  0.866025
# 3     0.778932  0.557143   0.363596        0.0   False       0.5  0.866025
# 4     0.689244  0.335714   0.357335        0.0   False       0.5  0.866025
# ...        ...       ...        ...        ...     ...       ...       ...
# 1091  0.617795  0.407143   0.112701        0.0   False      -0.0       1.0
# 1092  0.691212  0.271429   0.120751        0.0   False      -0.0       1.0
# 1093  0.681721  0.321429   0.320215        0.0   False      -0.0       1.0
# 1094  0.732688  0.421429   0.360465        0.0   False      -0.0       1.0
# 1095  0.801047  0.335714   0.281306        0.0   False      -0.0       1.0
#
#      season_sin season_cos   day_sin   day_cos     kg
# 0           0.0        1.0  0.201299   0.97953   5.36
# 1           0.0        1.0  0.394356  0.918958  22.92
# 2           0.0        1.0  0.571268  0.820763  34.39
# 3           0.0        1.0  0.724793  0.688967  10.66
# 4           0.0        1.0  0.848644  0.528964  11.42
# ...         ...        ...       ...       ...    ...
# 1091        0.0        1.0 -0.724793  0.688967  16.74
# 1092        0.0        1.0 -0.571268  0.820763   5.42
# 1093        0.0        1.0 -0.394356  0.918958  38.55
# 1094        0.0        1.0 -0.201299   0.97953  48.28
# 1095        0.0        1.0      -0.0       1.0  56.30
#
# [1096 rows x 12 columns]

# %%
df = concatFeaturesTarget(X, df_target[target], columns)
lags= 30
horizon= 14
roll_windows=(7,)
lagRoller = LagRoller(lags = lags, horizon = horizon, roll_windows = roll_windows)
lagRoller.fit(df)
# Out:
# LagRoller(lags=30)

# %%
lagRoller.get_feature_names_out()
# Out:
# array(['temp', 'humidity', 'wind_speed', 'clouds_all', 'holiday',
#        'month_sin', 'month_cos', 'season_sin', 'season_cos', 'day_sin',
#        'day_cos', 'kg', 'temp_lag_1', 'temp_lag_2', 'temp_lag_3',
#        'temp_lag_4', 'temp_lag_5', 'temp_lag_6', 'temp_lag_7',
#        'temp_lag_8', 'temp_lag_9', 'temp_lag_10', 'temp_lag_11',
#        'temp_lag_12', 'temp_lag_13', 'temp_lag_14', 'temp_lag_15',
#        'temp_lag_16', 'temp_lag_17', 'temp_lag_18', 'temp_lag_19',
#        'temp_lag_20', 'temp_lag_21', 'temp_lag_22', 'temp_lag_23',
#        'temp_lag_24', 'temp_lag_25', 'temp_lag_26', 'temp_lag_27',
#        'temp_lag_28', 'temp_lag_29', 'temp_lag_30', 'temp_roll7_mean',
#        'temp_roll7_std', 'humidity_lag_1', 'humidity_lag_2',
#        'humidity_lag_3', 'humidity_lag_4', 'humidity_lag_5',
#        'humidity_lag_6', 'humidity_lag_7', 'humidity_lag_8',
#        'humidity_lag_9', 'humidity_lag_10', 'humidity_lag_11',
#        'humidity_lag_12', 'humidity_lag_13', 'humidity_lag_14',
#        'humidity_lag_15', 'humidity_lag_16', 'humidity_lag_17',
#        'humidity_lag_18', 'humidity_lag_19', 'humidity_lag_20',
#        'humidity_lag_21', 'humidity_lag_22', 'humidity_lag_23',
#        'humidity_lag_24', 'humidity_lag_25', 'humidity_lag_26',
#        'humidity_lag_27', 'humidity_lag_28', 'humidity_lag_29',
#        'humidity_lag_30', 'humidity_roll7_mean', 'humidity_roll7_std',
#        'wind_speed_lag_1', 'wind_speed_lag_2', 'wind_speed_lag_3',
#        'wind_speed_lag_4', 'wind_speed_lag_5', 'wind_speed_lag_6',
#        'wind_speed_lag_7', 'wind_speed_lag_8', 'wind_speed_lag_9',
#        'wind_speed_lag_10', 'wind_speed_lag_11', 'wind_speed_lag_12',
#        'wind_speed_lag_13', 'wind_speed_lag_14', 'wind_speed_lag_15',
#        'wind_speed_lag_16', 'wind_speed_lag_17', 'wind_speed_lag_18',
#        'wind_speed_lag_19', 'wind_speed_lag_20', 'wind_speed_lag_21',
#        'wind_speed_lag_22', 'wind_speed_lag_23', 'wind_speed_lag_24',
#        'wind_speed_lag_25', 'wind_speed_lag_26', 'wind_speed_lag_27',
#        'wind_speed_lag_28', 'wind_speed_lag_29', 'wind_speed_lag_30',
#        'wind_speed_roll7_mean', 'wind_speed_roll7_std',
#        'clouds_all_lag_1', 'clouds_all_lag_2', 'clouds_all_lag_3',
#        'clouds_all_lag_4', 'clouds_all_lag_5', 'clouds_all_lag_6',
#        'clouds_all_lag_7', 'clouds_all_lag_8', 'clouds_all_lag_9',
#        'clouds_all_lag_10', 'clouds_all_lag_11', 'clouds_all_lag_12',
#        'clouds_all_lag_13', 'clouds_all_lag_14', 'clouds_all_lag_15',
#        'clouds_all_lag_16', 'clouds_all_lag_17', 'clouds_all_lag_18',
#        'clouds_all_lag_19', 'clouds_all_lag_20', 'clouds_all_lag_21',
#        'clouds_all_lag_22', 'clouds_all_lag_23', 'clouds_all_lag_24',
#        'clouds_all_lag_25', 'clouds_all_lag_26', 'clouds_all_lag_27',
#        'clouds_all_lag_28', 'clouds_all_lag_29', 'clouds_all_lag_30',
#        'clouds_all_roll7_mean', 'clouds_all_roll7_std', 'holiday_lag_1',
#        'holiday_lag_2', 'holiday_lag_3', 'holiday_lag_4', 'holiday_lag_5',
#        'holiday_lag_6', 'holiday_lag_7', 'holiday_lag_8', 'holiday_lag_9',
#        'holiday_lag_10', 'holiday_lag_11', 'holiday_lag_12',
#        'holiday_lag_13', 'holiday_lag_14', 'holiday_lag_15',
#        'holiday_lag_16', 'holiday_lag_17', 'holiday_lag_18',
#        'holiday_lag_19', 'holiday_lag_20', 'holiday_lag_21',
#        'holiday_lag_22', 'holiday_lag_23', 'holiday_lag_24',
#        'holiday_lag_25', 'holiday_lag_26', 'holiday_lag_27',
#        'holiday_lag_28', 'holiday_lag_29', 'holiday_lag_30',
#        'holiday_roll7_mean', 'holiday_roll7_std', 'month_sin_lag_1',
#        'month_sin_lag_2', 'month_sin_lag_3', 'month_sin_lag_4',
#        'month_sin_lag_5', 'month_sin_lag_6', 'month_sin_lag_7',
#        'month_sin_lag_8', 'month_sin_lag_9', 'month_sin_lag_10',
#        'month_sin_lag_11', 'month_sin_lag_12', 'month_sin_lag_13',
#        'month_sin_lag_14', 'month_sin_lag_15', 'month_sin_lag_16',
#        'month_sin_lag_17', 'month_sin_lag_18', 'month_sin_lag_19',
#        'month_sin_lag_20', 'month_sin_lag_21', 'month_sin_lag_22',
#        'month_sin_lag_23', 'month_sin_lag_24', 'month_sin_lag_25',
#        'month_sin_lag_26', 'month_sin_lag_27', 'month_sin_lag_28',
#        'month_sin_lag_29', 'month_sin_lag_30', 'month_sin_roll7_mean',
#        'month_sin_roll7_std', 'month_cos_lag_1', 'month_cos_lag_2',
#        'month_cos_lag_3', 'month_cos_lag_4', 'month_cos_lag_5',
#        'month_cos_lag_6', 'month_cos_lag_7', 'month_cos_lag_8',
#        'month_cos_lag_9', 'month_cos_lag_10', 'month_cos_lag_11',
#        'month_cos_lag_12', 'month_cos_lag_13', 'month_cos_lag_14',
#        'month_cos_lag_15', 'month_cos_lag_16', 'month_cos_lag_17',
#        'month_cos_lag_18', 'month_cos_lag_19', 'month_cos_lag_20',
#        'month_cos_lag_21', 'month_cos_lag_22', 'month_cos_lag_23',
#        'month_cos_lag_24', 'month_cos_lag_25', 'month_cos_lag_26',
#        'month_cos_lag_27', 'month_cos_lag_28', 'month_cos_lag_29',
#        'month_cos_lag_30', 'month_cos_roll7_mean', 'month_cos_roll7_std',
#        'season_sin_lag_1', 'season_sin_lag_2', 'season_sin_lag_3',
#        'season_sin_lag_4', 'season_sin_lag_5', 'season_sin_lag_6',
#        'season_sin_lag_7', 'season_sin_lag_8', 'season_sin_lag_9',
#        'season_sin_lag_10', 'season_sin_lag_11', 'season_sin_lag_12',
#        'season_sin_lag_13', 'season_sin_lag_14', 'season_sin_lag_15',
#        'season_sin_lag_16', 'season_sin_lag_17', 'season_sin_lag_18',
#        'season_sin_lag_19', 'season_sin_lag_20', 'season_sin_lag_21',
#        'season_sin_lag_22', 'season_sin_lag_23', 'season_sin_lag_24',
#        'season_sin_lag_25', 'season_sin_lag_26', 'season_sin_lag_27',
#        'season_sin_lag_28', 'season_sin_lag_29', 'season_sin_lag_30',
#        'season_sin_roll7_mean', 'season_sin_roll7_std',
#        'season_cos_lag_1', 'season_cos_lag_2', 'season_cos_lag_3',
#        'season_cos_lag_4', 'season_cos_lag_5', 'season_cos_lag_6',
#        'season_cos_lag_7', 'season_cos_lag_8', 'season_cos_lag_9',
#        'season_cos_lag_10', 'season_cos_lag_11', 'season_cos_lag_12',
#        'season_cos_lag_13', 'season_cos_lag_14', 'season_cos_lag_15',
#        'season_cos_lag_16', 'season_cos_lag_17', 'season_cos_lag_18',
#        'season_cos_lag_19', 'season_cos_lag_20', 'season_cos_lag_21',
#        'season_cos_lag_22', 'season_cos_lag_23', 'season_cos_lag_24',
#        'season_cos_lag_25', 'season_cos_lag_26', 'season_cos_lag_27',
#        'season_cos_lag_28', 'season_cos_lag_29', 'season_cos_lag_30',
#        'season_cos_roll7_mean', 'season_cos_roll7_std', 'day_sin_lag_1',
#        'day_sin_lag_2', 'day_sin_lag_3', 'day_sin_lag_4', 'day_sin_lag_5',
#        'day_sin_lag_6', 'day_sin_lag_7', 'day_sin_lag_8', 'day_sin_lag_9',
#        'day_sin_lag_10', 'day_sin_lag_11', 'day_sin_lag_12',
#        'day_sin_lag_13', 'day_sin_lag_14', 'day_sin_lag_15',
#        'day_sin_lag_16', 'day_sin_lag_17', 'day_sin_lag_18',
#        'day_sin_lag_19', 'day_sin_lag_20', 'day_sin_lag_21',
#        'day_sin_lag_22', 'day_sin_lag_23', 'day_sin_lag_24',
#        'day_sin_lag_25', 'day_sin_lag_26', 'day_sin_lag_27',
#        'day_sin_lag_28', 'day_sin_lag_29', 'day_sin_lag_30',
#        'day_sin_roll7_mean', 'day_sin_roll7_std', 'day_cos_lag_1',
#        'day_cos_lag_2', 'day_cos_lag_3', 'day_cos_lag_4', 'day_cos_lag_5',
#        'day_cos_lag_6', 'day_cos_lag_7', 'day_cos_lag_8', 'day_cos_lag_9',
#        'day_cos_lag_10', 'day_cos_lag_11', 'day_cos_lag_12',
#        'day_cos_lag_13', 'day_cos_lag_14', 'day_cos_lag_15',
#        'day_cos_lag_16', 'day_cos_lag_17', 'day_cos_lag_18',
#        'day_cos_lag_19', 'day_cos_lag_20', 'day_cos_lag_21',
#        'day_cos_lag_22', 'day_cos_lag_23', 'day_cos_lag_24',
#        'day_cos_lag_25', 'day_cos_lag_26', 'day_cos_lag_27',
#        'day_cos_lag_28', 'day_cos_lag_29', 'day_cos_lag_30',
#        'day_cos_roll7_mean', 'day_cos_roll7_std', 'kg_lag_1', 'kg_lag_2',
#        'kg_lag_3', 'kg_lag_4', 'kg_lag_5', 'kg_lag_6', 'kg_lag_7',
#        'kg_lag_8', 'kg_lag_9', 'kg_lag_10', 'kg_lag_11', 'kg_lag_12',
#        'kg_lag_13', 'kg_lag_14', 'kg_lag_15', 'kg_lag_16', 'kg_lag_17',
#        'kg_lag_18', 'kg_lag_19', 'kg_lag_20', 'kg_lag_21', 'kg_lag_22',
#        'kg_lag_23', 'kg_lag_24', 'kg_lag_25', 'kg_lag_26', 'kg_lag_27',
#        'kg_lag_28', 'kg_lag_29', 'kg_lag_30', 'kg_roll7_mean',
#        'kg_roll7_std', 'temp_t_plus_1', 'temp_t_plus_2', 'temp_t_plus_3',
#        'temp_t_plus_4', 'temp_t_plus_5', 'temp_t_plus_6', 'temp_t_plus_7',
#        'temp_t_plus_8', 'temp_t_plus_9', 'temp_t_plus_10',
#        'temp_t_plus_11', 'temp_t_plus_12', 'temp_t_plus_13',
#        'temp_t_plus_14', 'humidity_t_plus_1', 'humidity_t_plus_2',
#        'humidity_t_plus_3', 'humidity_t_plus_4', 'humidity_t_plus_5',
#        'humidity_t_plus_6', 'humidity_t_plus_7', 'humidity_t_plus_8',
#        'humidity_t_plus_9', 'humidity_t_plus_10', 'humidity_t_plus_11',
#        'humidity_t_plus_12', 'humidity_t_plus_13', 'humidity_t_plus_14',
#        'wind_speed_t_plus_1', 'wind_speed_t_plus_2',
#        'wind_speed_t_plus_3', 'wind_speed_t_plus_4',
#        'wind_speed_t_plus_5', 'wind_speed_t_plus_6',
#        'wind_speed_t_plus_7', 'wind_speed_t_plus_8',
#        'wind_speed_t_plus_9', 'wind_speed_t_plus_10',
#        'wind_speed_t_plus_11', 'wind_speed_t_plus_12',
#        'wind_speed_t_plus_13', 'wind_speed_t_plus_14',
#        'clouds_all_t_plus_1', 'clouds_all_t_plus_2',
#        'clouds_all_t_plus_3', 'clouds_all_t_plus_4',
#        'clouds_all_t_plus_5', 'clouds_all_t_plus_6',
#        'clouds_all_t_plus_7', 'clouds_all_t_plus_8',
#        'clouds_all_t_plus_9', 'clouds_all_t_plus_10',
#        'clouds_all_t_plus_11', 'clouds_all_t_plus_12',
#        'clouds_all_t_plus_13', 'clouds_all_t_plus_14', 'holiday_t_plus_1',
#        'holiday_t_plus_2', 'holiday_t_plus_3', 'holiday_t_plus_4',
#        'holiday_t_plus_5', 'holiday_t_plus_6', 'holiday_t_plus_7',
#        'holiday_t_plus_8', 'holiday_t_plus_9', 'holiday_t_plus_10',
#        'holiday_t_plus_11', 'holiday_t_plus_12', 'holiday_t_plus_13',
#        'holiday_t_plus_14', 'month_sin_t_plus_1', 'month_sin_t_plus_2',
#        'month_sin_t_plus_3', 'month_sin_t_plus_4', 'month_sin_t_plus_5',
#        'month_sin_t_plus_6', 'month_sin_t_plus_7', 'month_sin_t_plus_8',
#        'month_sin_t_plus_9', 'month_sin_t_plus_10', 'month_sin_t_plus_11',
#        'month_sin_t_plus_12', 'month_sin_t_plus_13',
#        'month_sin_t_plus_14', 'month_cos_t_plus_1', 'month_cos_t_plus_2',
#        'month_cos_t_plus_3', 'month_cos_t_plus_4', 'month_cos_t_plus_5',
#        'month_cos_t_plus_6', 'month_cos_t_plus_7', 'month_cos_t_plus_8',
#        'month_cos_t_plus_9', 'month_cos_t_plus_10', 'month_cos_t_plus_11',
#        'month_cos_t_plus_12', 'month_cos_t_plus_13',
#        'month_cos_t_plus_14', 'season_sin_t_plus_1',
#        'season_sin_t_plus_2', 'season_sin_t_plus_3',
#        'season_sin_t_plus_4', 'season_sin_t_plus_5',
#        'season_sin_t_plus_6', 'season_sin_t_plus_7',
#        'season_sin_t_plus_8', 'season_sin_t_plus_9',
#        'season_sin_t_plus_10', 'season_sin_t_plus_11',
#        'season_sin_t_plus_12', 'season_sin_t_plus_13',
#        'season_sin_t_plus_14', 'season_cos_t_plus_1',
#        'season_cos_t_plus_2', 'season_cos_t_plus_3',
#        'season_cos_t_plus_4', 'season_cos_t_plus_5',
#        'season_cos_t_plus_6', 'season_cos_t_plus_7',
#        'season_cos_t_plus_8', 'season_cos_t_plus_9',
#        'season_cos_t_plus_10', 'season_cos_t_plus_11',
#        'season_cos_t_plus_12', 'season_cos_t_plus_13',
#        'season_cos_t_plus_14', 'day_sin_t_plus_1', 'day_sin_t_plus_2',
#        'day_sin_t_plus_3', 'day_sin_t_plus_4', 'day_sin_t_plus_5',
#        'day_sin_t_plus_6', 'day_sin_t_plus_7', 'day_sin_t_plus_8',
#        'day_sin_t_plus_9', 'day_sin_t_plus_10', 'day_sin_t_plus_11',
#        'day_sin_t_plus_12', 'day_sin_t_plus_13', 'day_sin_t_plus_14',
#        'day_cos_t_plus_1', 'day_cos_t_plus_2', 'day_cos_t_plus_3',
#        'day_cos_t_plus_4', 'day_cos_t_plus_5', 'day_cos_t_plus_6',
#        'day_cos_t_plus_7', 'day_cos_t_plus_8', 'day_cos_t_plus_9',
#        'day_cos_t_plus_10', 'day_cos_t_plus_11', 'day_cos_t_plus_12',
#        'day_cos_t_plus_13', 'day_cos_t_plus_14', 'kg_t_plus_1',
#        'kg_t_plus_2', 'kg_t_plus_3', 'kg_t_plus_4', 'kg_t_plus_5',
#        'kg_t_plus_6', 'kg_t_plus_7', 'kg_t_plus_8', 'kg_t_plus_9',
#        'kg_t_plus_10', 'kg_t_plus_11', 'kg_t_plus_12', 'kg_t_plus_13',
#        'kg_t_plus_14'], dtype=object)

# %%
df_lag = lagRoller.transform(df)
# Out:
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_roll{w}_mean"] = df[col].rolling(w).mean().shift(1)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_roll{w}_std"] = df[col].rolling(w).std().shift(1)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_roll{w}_mean"] = df[col].rolling(w).mean().shift(1)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_roll{w}_std"] = df[col].rolling(w).std().shift(1)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_roll{w}_mean"] = df[col].rolling(w).mean().shift(1)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_roll{w}_std"] = df[col].rolling(w).std().shift(1)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{i}"] = df[col].shift(i)
# ...
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)
# c:\Users\IA-41\OneDrive - inteligenciaanalitica.com\IA Privado\Recursos\LGA\Práctica IA\src\features\my_transformers.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_t_plus_{h}"] = df[col].shift(-h)

# %%
df_lag
# Out:
#           temp  humidity wind_speed clouds_all holiday month_sin month_cos  \
# 30    0.676021  0.535714   0.311717        0.0   False       0.5  0.866025
# 31    0.705878       0.3   0.242397        0.0   False  0.866025       0.5
# 32    0.834169  0.421429   0.219589        0.0   False  0.866025       0.5
# 33    0.697896  0.742857   0.242397       0.75   False  0.866025       0.5
# 34    0.678732  0.771429   0.150268        0.4   False  0.866025       0.5
# ...        ...       ...        ...        ...     ...       ...       ...
# 1077   0.69923  0.314286   0.520572        0.0   False      -0.0       1.0
# 1078  0.687203  0.314286   0.288909        0.0   False      -0.0       1.0
# 1079  0.672012  0.471429   0.288909        0.0   False      -0.0       1.0
# 1080  0.592967  0.328571   0.600179        0.0   False      -0.0       1.0
# 1081  0.650844  0.328571   0.279964        0.0   False      -0.0       1.0
#
#      season_sin season_cos   day_sin  ... kg_t_plus_5  kg_t_plus_6  \
# 30          0.0        1.0      -0.0  ...       16.37         5.53
# 31          0.0        1.0  0.201299  ...        5.53        27.19
# 32          0.0        1.0  0.394356  ...       27.19         5.55
# 33          0.0        1.0  0.571268  ...        5.55        17.14
# 34          0.0        1.0  0.724793  ...       17.14        38.92
# ...         ...        ...       ...  ...         ...          ...
# 1077       -1.0       -0.0  0.485302  ...       10.58        21.70
# 1078       -1.0       -0.0  0.299363  ...       21.70         4.18
# 1079       -1.0       -0.0  0.101168  ...        4.18        29.64
# 1080       -1.0       -0.0 -0.101168  ...       29.64        31.33
# 1081       -1.0       -0.0 -0.299363  ...       31.33        36.02
#
#      kg_t_plus_7 kg_t_plus_8 kg_t_plus_9 kg_t_plus_10 kg_t_plus_11  \
# 30         27.19        5.55       17.14        38.92        11.31
# 31          5.55       17.14       38.92        11.31        27.66
# 32         17.14       38.92       11.31        27.66        22.83
# 33         38.92       11.31       27.66        22.83        22.32
# 34         11.31       27.66       22.83        22.32        10.25
# ...          ...         ...         ...          ...          ...
# 1077        4.18       29.64       31.33        36.02        56.94
# 1078       29.64       31.33       36.02        56.94        16.31
# 1079       31.33       36.02       56.94        16.31        38.89
# 1080       36.02       56.94       16.31        38.89        16.74
# 1081       56.94       16.31       38.89        16.74         5.42
#
#      kg_t_plus_12 kg_t_plus_13 kg_t_plus_14
# 30          27.66        22.83        22.32
# 31          22.83        22.32        10.25
# 32          22.32        10.25        10.69
# 33          10.25        10.69        17.44
# 34          10.69        17.44        16.78
# ...           ...          ...          ...
# 1077        16.31        38.89        16.74
# 1078        38.89        16.74         5.42
# 1079        16.74         5.42        38.55
# 1080         5.42        38.55        48.28
# 1081        38.55        48.28        56.30
#
# [1052 rows x 564 columns]

# %%
import pandas as pd, numpy as np
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

data = df_lag
#X = data.filter(like='lag_').join(data[['roll7_mean', 'roll7_std']])
X = data.filter(like='lag_').join(data.filter(like='roll7_'))
y = data[[f'kg_t_plus_{h}' for h in range(1, horizon+1)]]

# ── 3. Split temporal (sin barajar) ───────────────────────────
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, shuffle=False)

# %%
# justo antes de .fit(...)
X_train = X_train.astype('float32')
X_val   = X_val.astype('float32')
X = X.astype('float32')

# %%
# ── 4. Modelo XGBoost ────────────────────────────────────────
xgb_params = dict(
    n_estimators=500,
    learning_rate=0.01,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42
)

base_model = XGBRegressor(**xgb_params)
model      = MultiOutputRegressor(base_model, n_jobs=-1)

model.fit(X_train, y_train)
# Out:
# MAE validación (14 días promedio): 8.392
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\data.py", line 407, in pandas_feature_info
#     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#                              ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\externals\loky\process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\sklearn.py", line 1327, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py", line 2665, in inplace_predict
#     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\data.py", line 640, in _transform_pandas_df
#     feature_names, feature_types = pandas_feature_info(
#                                    ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\data.py", line 409, in pandas_feature_info
#     _invalid_dataframe_dtype(data)
#   File "C:\Users\IA-41\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\data.py", line 372, in _invalid_dataframe_dtype
#     raise ValueError(msg)
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:temp_lag_1: object, temp_lag_2: object, temp_lag_3: object, temp_lag_4: object, temp_lag_5: object, temp_lag_6: object, temp_lag_7: object, temp_lag_8: object, temp_lag_9: object, temp_lag_10: object, temp_lag_11: object, temp_lag_12: object, temp_lag_13: object, temp_lag_14: object, temp_lag_15: object, temp_lag_16: object, temp_lag_17: object, temp_lag_18: object, temp_lag_19: object, temp_lag_20: object, temp_lag_21: object, temp_lag_22: object, temp_lag_23: object, temp_lag_24: object, temp_lag_25: object, temp_lag_26: object, temp_lag_27: object, temp_lag_28: object, temp_lag_29: object, temp_lag_30: object, humidity_lag_1: object, humidity_lag_2: object, humidity_lag_3: object, humidity_lag_4: object, humidity_lag_5: object, humidity_lag_6: object, humidity_lag_7: object, humidity_lag_8: object, humidity_lag_9: object, humidity_lag_10: object, humidity_lag_11: object, humidity_lag_12: object, humidity_lag_13: object, humidity_lag_14: object, humidity_lag_15: object, humidity_lag_16: object, humidity_lag_17: object, humidity_lag_18: object, humidity_lag_19: object, humidity_lag_20: object, humidity_lag_21: object, humidity_lag_22: object, humidity_lag_23: object, humidity_lag_24: object, humidity_lag_25: object, humidity_lag_26: object, humidity_lag_27: object, humidity_lag_28: object, humidity_lag_29: object, humidity_lag_30: object, wind_speed_lag_1: object, wind_speed_lag_2: object, wind_speed_lag_3: object, wind_speed_lag_4: object, wind_speed_lag_5: object, wind_speed_lag_6: object, wind_speed_lag_7: object, wind_speed_lag_8: object, wind_speed_lag_9: object, wind_speed_lag_10: object, wind_speed_lag_11: object, wind_speed_lag_12: object, wind_speed_lag_13: object, wind_speed_lag_14: object, wind_speed_lag_15: object, wind_speed_lag_16: object, wind_speed_lag_17: object, wind_speed_lag_18: object, wind_speed_lag_19: object, wind_speed_lag_20: object, wind_speed_lag_21: object, wind_speed_lag_22: object, wind_speed_lag_23: object, wind_speed_lag_24: object, wind_speed_lag_25: object, wind_speed_lag_26: object, wind_speed_lag_27: object, wind_speed_lag_28: object, wind_speed_lag_29: object, wind_speed_lag_30: object, clouds_all_lag_1: object, clouds_all_lag_2: object, clouds_all_lag_3: object, clouds_all_lag_4: object, clouds_all_lag_5: object, clouds_all_lag_6: object, clouds_all_lag_7: object, clouds_all_lag_8: object, clouds_all_lag_9: object, clouds_all_lag_10: object, clouds_all_lag_11: object, clouds_all_lag_12: object, clouds_all_lag_13: object, clouds_all_lag_14: object, clouds_all_lag_15: object, clouds_all_lag_16: object, clouds_all_lag_17: object, clouds_all_lag_18: object, clouds_all_lag_19: object, clouds_all_lag_20: object, clouds_all_lag_21: object, clouds_all_lag_22: object, clouds_all_lag_23: object, clouds_all_lag_24: object, clouds_all_lag_25: object, clouds_all_lag_26: object, clouds_all_lag_27: object, clouds_all_lag_28: object, clouds_all_lag_29: object, clouds_all_lag_30: object, holiday_lag_1: object, holiday_lag_2: object, holiday_lag_3: object, holiday_lag_4: object, holiday_lag_5: object, holiday_lag_6: object, holiday_lag_7: object, holiday_lag_8: object, holiday_lag_9: object, holiday_lag_10: object, holiday_lag_11: object, holiday_lag_12: object, holiday_lag_13: object, holiday_lag_14: object, holiday_lag_15: object, holiday_lag_16: object, holiday_lag_17: object, holiday_lag_18: object, holiday_lag_19: object, holiday_lag_20: object, holiday_lag_21: object, holiday_lag_22: object, holiday_lag_23: object, holiday_lag_24: object, holiday_lag_25: object, holiday_lag_26: object, holiday_lag_27: object, holiday_lag_28: object, holiday_lag_29: object, holiday_lag_30: object, month_sin_lag_1: object, month_sin_lag_2: object, month_sin_lag_3: object, month_sin_lag_4: object, month_sin_lag_5: ob ...
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 24
#      22 # ── 6. Pronóstico futuro ─────────────────────────────────────
#      23 last_row = X.tail(1)                     # features hasta hoy
# ---> 24 forecast_scaled = model.predict(last_row)[0]  # array(14,)
#      25 # si habías escalado antes, des-escala aquí.  (robust, min-max, etc.)
#      26 print("Pronóstico próximos 14 días:", forecast_scaled)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\multioutput.py:310, in _MultiOutputEstimator.predict(self, X)
#     307 if not hasattr(self.estimators_[0], "predict"):
#     308     raise ValueError("The base estimator should implement a predict method")
# --> 310 y = Parallel(n_jobs=self.n_jobs)(
#     311     delayed(e.predict)(X) for e in self.estimators_
#     312 )
#     314 return np.asarray(y).T
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:temp_lag_1: object, temp_lag_2: object, temp_lag_3: object, temp_lag_4: object, temp_lag_5: object, temp_lag_6: object, temp_lag_7: object, temp_lag_8: object, temp_lag_9: object, temp_lag_10: object, temp_lag_11: object, temp_lag_12: object, temp_lag_13: object, temp_lag_14: object, temp_lag_15: object, temp_lag_16: object, temp_lag_17: object, temp_lag_18: object, temp_lag_19: object, temp_lag_20: object, temp_lag_21: object, temp_lag_22: object, temp_lag_23: object, temp_lag_24: object, temp_lag_25: object, temp_lag_26: object, temp_lag_27: object, temp_lag_28: object, temp_lag_29: object, temp_lag_30: object, humidity_lag_1: object, humidity_lag_2: object, humidity_lag_3: object, humidity_lag_4: object, humidity_lag_5: object, humidity_lag_6: object, humidity_lag_7: object, humidity_lag_8: object, humidity_lag_9: object, humidity_lag_10: object, humidity_lag_11: object, humidity_lag_12: object, humidity_lag_13: object, humidity_lag_14: object, humidity_lag_15: object, humidity_lag_16: object, humidity_lag_17: object, humidity_lag_18: object, humidity_lag_19: object, humidity_lag_20: object, humidity_lag_21: object, humidity_lag_22: object, humidity_lag_23: object, humidity_lag_24: object, humidity_lag_25: object, humidity_lag_26: object, humidity_lag_27: object, humidity_lag_28: object, humidity_lag_29: object, humidity_lag_30: object, wind_speed_lag_1: object, wind_speed_lag_2: object, wind_speed_lag_3: object, wind_speed_lag_4: object, wind_speed_lag_5: object, wind_speed_lag_6: object, wind_speed_lag_7: object, wind_speed_lag_8: object, wind_speed_lag_9: object, wind_speed_lag_10: object, wind_speed_lag_11: object, wind_speed_lag_12: object, wind_speed_lag_13: object, wind_speed_lag_14: object, wind_speed_lag_15: object, wind_speed_lag_16: object, wind_speed_lag_17: object, wind_speed_lag_18: object, wind_speed_lag_19: object, wind_speed_lag_20: object, wind_speed_lag_21: object, wind_speed_lag_22: object, wind_speed_lag_23: object, wind_speed_lag_24: object, wind_speed_lag_25: object, wind_speed_lag_26: object, wind_speed_lag_27: object, wind_speed_lag_28: object, wind_speed_lag_29: object, wind_speed_lag_30: object, clouds_all_lag_1: object, clouds_all_lag_2: object, clouds_all_lag_3: object, clouds_all_lag_4: object, clouds_all_lag_5: object, clouds_all_lag_6: object, clouds_all_lag_7: object, clouds_all_lag_8: object, clouds_all_lag_9: object, clouds_all_lag_10: object, clouds_all_lag_11: object, clouds_all_lag_12: object, clouds_all_lag_13: object, clouds_all_lag_14: object, clouds_all_lag_15: object, clouds_all_lag_16: object, clouds_all_lag_17: object, clouds_all_lag_18: object, clouds_all_lag_19: object, clouds_all_lag_20: object, clouds_all_lag_21: object, clouds_all_lag_22: object, clouds_all_lag_23: object, clouds_all_lag_24: object, clouds_all_lag_25: object, clouds_all_lag_26: object, clouds_all_lag_27: object, clouds_all_lag_28: object, clouds_all_lag_29: object, clouds_all_lag_30: object, holiday_lag_1: object, holiday_lag_2: object, holiday_lag_3: object, holiday_lag_4: object, holiday_lag_5: object, holiday_lag_6: object, holiday_lag_7: object, holiday_lag_8: object, holiday_lag_9: object, holiday_lag_10: object, holiday_lag_11: object, holiday_lag_12: object, holiday_lag_13: object, holiday_lag_14: object, holiday_lag_15: object, holiday_lag_16: object, holiday_lag_17: object, holiday_lag_18: object, holiday_lag_19: object, holiday_lag_20: object, holiday_lag_21: object, holiday_lag_22: object, holiday_lag_23: object, holiday_lag_24: object, holiday_lag_25: object, holiday_lag_26: object, holiday_lag_27: object, holiday_lag_28: object, holiday_lag_29: object, holiday_lag_30: object, month_sin_lag_1: object, month_sin_lag_2: object, month_sin_lag_3: object, month_sin_lag_4: object, month_sin_lag_5: ob ...

# %%
# ── 5. Evaluación rápida ─────────────────────────────────────
pred_val = model.predict(X_val)
mae      = mean_absolute_error(y_val, pred_val)
print(f"MAE validación (14 días promedio): {mae:0.3f}")

# ── 6. Pronóstico futuro ─────────────────────────────────────
last_row = X.tail(1)                     # features hasta hoy
forecast_scaled = model.predict(last_row)[0]  # array(14,)
# si habías escalado antes, des-escala aquí.  (robust, min-max, etc.)
print("Pronóstico próximos 14 días:", forecast_scaled)
# Out:
# MAE validación (14 días promedio): 8.392
# Pronóstico próximos 14 días: [16.134127 14.364522 19.690939 27.06571  24.530418 22.763205 26.189808
#  21.72269  18.283482 25.0611   31.675068 21.597404 19.4157   19.946676]
